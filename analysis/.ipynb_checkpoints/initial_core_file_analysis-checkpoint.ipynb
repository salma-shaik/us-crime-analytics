# %% [markdown]
# __Load the required libraries__

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:20,.4f}'.format
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 500)

# %% [markdown]
# __Load the initial core file.
#   Display the list of columns.
#   Display the top 5 records.__

# %%
initial_core_df = pd.read_csv('C:/Users/sshaik2/projects/criminal_justice/us-crime-analytics/data/analysis/initial_core_file.csv')

print(list(initial_core_df))
print(initial_core_df.head())
# Out:
# ['ORI', 'AGENCY', 'placename', 'Govt_level', 'place_fips', 'STATEFP', 'CNTY', 'YEAR', 'POP100', 'White_count', 'Black_count', 'Hispanic_count', 'Age1524_WhiteM', 'White_Males_All', 'Age1524_WhiteF', 'White_Females_All', 'Age1524_BlackM', 'Black_Males_All', 'Age1524_BlackF', 'Black_Females_All', 'Hispanic_Males_All', 'Age1524_HispanicM', 'Age1524_HispanicF', 'Hispanic_Females_All', 'Pct_WYM', 'Pct_WYF', 'total_count_county', 'population', 'murder', 'rape', 'robbery', 'aggravated_assault', 'simple_assault', 'burglary', 'larceny', 'auto_theft', 'violent_crime', 'property_crime', 'total_main_crime', 'murder_rate', 'rape_rate', 'robbery_rate', 'aggravated_assault_rate', 'simple_assault_rate', 'burglary_rate', 'larceny_rate', 'auto_theft_rate', 'violent_crime_rate', 'property_crime_rate', 'total_main_crime_rate', 'violent_arrests', 'property_arrests', 'total_main_arrests', 'violent_arrests_rates', 'property_arrests_rates', 'total_main_arrests_rates', 'sale_drug_total_tot_arrests_rate', 'poss_drug_total_tot_arrests_rate', 'disorder_arrests_tot_index_rate', 'pci_total_pop', 'pci_white', 'pci_black', 'pci_hisp', 'emp_total', 'emp_total_male', 'emp_total_female', 'emp_total_male_white', 'emp_total_female_white', 'emp_total_male_black', 'emp_total_female_black', 'emp_total_male_hisp', 'emp_total_female_hisp', 'emp_total_white', 'emp_total_black', 'emp_total_hisp', 'PRIMARY_LATITUDE', 'PRIMARY_LONGITUDE', 'total_officers', 'total_officers_rate', 'perc_felonies', 'perc_misdemeanors', 'prison_occupancy_count', 'jail_occupancy_count', 'icspr_rep_code']
#        ORI     AGENCY               placename  Govt_level  place_fips  \
# 0  AK00101  ANCHORAGE  Anchorage municipality           2        3000
# 1  AK00101  ANCHORAGE  Anchorage municipality           2        3000
# 2  AK00101  ANCHORAGE  Anchorage municipality           2        3000
# 3  AK00101  ANCHORAGE  Anchorage municipality           2        3000
# 4  AK00101  ANCHORAGE  Anchorage municipality           2        3000
#
#    STATEFP  CNTY  YEAR               POP100          White_count  \
# 0        2    20  2015         307,598.0000         194,742.0000
# 1        2    20  2014         304,443.6000         194,293.2000
# 2        2    20  2013         301,289.2000         193,844.4000
# 3        2    20  2012         298,134.8000         193,395.6000
# 4        2    20  2011         294,980.4000         192,946.8000
#
#            Black_count       Hispanic_count       Age1524_WhiteM  \
# 0          16,740.0000          25,692.0000          15,564.0000
# 1          16,637.2000          24,965.8000          15,405.2000
# 2          16,534.4000          24,239.6000          15,246.4000
# 3          16,431.6000          23,513.4000          15,087.6000
# 4          16,328.8000          22,787.2000          14,928.8000
#
#        White_Males_All       Age1524_WhiteF    White_Females_All  \
# 0         101,409.0000          12,886.0000          93,334.0000
# 1         101,102.2000          12,831.2000          93,191.8000
# 2         100,795.4000          12,776.4000          93,049.6000
# 3         100,488.6000          12,721.6000          92,907.4000
# 4         100,181.8000          12,666.8000          92,765.2000
#
#         Age1524_BlackM      Black_Males_All       Age1524_BlackF  \
# 0           1,676.0000           9,004.0000           1,321.0000
# 1           1,655.8000           8,926.8000           1,311.2000
# 2           1,635.6000           8,849.6000           1,301.4000
# 3           1,615.4000           8,772.4000           1,291.6000
# 4           1,595.2000           8,695.2000           1,281.8000
#
#      Black_Females_All   Hispanic_Males_All    Age1524_HispanicM  \
# 0           7,735.0000          12,754.0000           2,672.0000
# 1           7,709.6000          12,399.6000           2,589.4000
# 2           7,684.2000          12,045.2000           2,506.8000
# 3           7,658.8000          11,690.8000           2,424.2000
# 4           7,633.4000          11,336.4000           2,341.6000
#
#      Age1524_HispanicF  Hispanic_Females_All              Pct_WYM  \
# 0           2,408.0000           12,938.0000               0.1537
# 1           2,334.4000           12,566.2000               0.1526
# 2           2,260.8000           12,194.4000               0.1514
# 3           2,187.2000           11,822.6000               0.1502
# 4           2,113.6000           11,450.8000               0.1491
#
#                Pct_WYF   total_count_county           population  \
# 0               0.1381         298,695.0000         301,239.0000
# 1               0.1377         301,010.0000         299,356.4000
# 2               0.1373         300,950.0000         297,473.8000
# 3               0.1369         298,610.0000         295,591.2000
# 4               0.1366         295,570.0000         293,708.6000
#
#                 murder                 rape              robbery  \
# 0              26.0000             517.0000             621.0000
# 1              12.0000             392.0000             496.0000
# 2              14.0000             408.0000             522.0000
# 3              15.0000             303.0000             488.0000
# 4              12.0000             283.0000             465.0000
#
#     aggravated_assault       simple_assault             burglary  \
# 0           2,062.0000           4,341.0000           1,685.0000
# 1           1,705.0000           4,031.0000           1,375.0000
# 2           1,491.0000           3,780.0000           1,318.0000
# 3           1,673.0000           4,377.0000           1,158.0000
# 4           1,628.0000           4,438.0000           1,080.0000
#
#                larceny           auto_theft        violent_crime  \
# 0           8,962.0000             814.0000           3,226.0000
# 1           9,217.0000             673.0000           2,605.0000
# 2           9,845.0000             627.0000           2,435.0000
# 3           8,554.0000             545.0000           2,479.0000
# 4           7,750.0000             407.0000           2,388.0000
#
#         property_crime     total_main_crime          murder_rate  \
# 0          11,461.0000          14,687.0000               8.6310
# 1          11,265.0000          13,870.0000               4.0086
# 2          11,790.0000          14,225.0000               4.7063
# 3          10,257.0000          12,736.0000               5.0746
# 4           9,237.0000          11,625.0000               4.0857
#
#              rape_rate         robbery_rate  aggravated_assault_rate  \
# 0             171.6245             206.1486                 684.5063
# 1             130.9476             165.6888                 569.5552
# 2             137.1549             175.4776                 501.2206
# 3             102.5064             165.0929                 565.9844
# 4              96.3540             158.3202                 554.2909
#
#    simple_assault_rate        burglary_rate         larceny_rate  \
# 0           1,441.0485             559.3565           2,975.0464
# 1           1,346.5555             459.3187           3,078.9387
# 2           1,270.7001             443.0642           3,309.5352
# 3           1,480.7613             391.7573           2,893.8615
# 4           1,511.0215             367.7114           2,638.6698
#
#        auto_theft_rate   violent_crime_rate  property_crime_rate  \
# 0             270.2173           1,070.9105           3,804.6203
# 1             224.8156             871.2024           3,763.0730
# 2             210.7749             819.2318           3,963.3743
# 3             184.3763             838.9966           3,469.9950
# 4             138.5727             813.3912           3,144.9539
#
#    total_main_crime_rate      violent_arrests     property_arrests  \
# 0             4,875.5307           1,138.0000           1,868.0000
# 1             4,634.2754           1,050.0000           2,101.0000
# 2             4,782.6061           1,064.0000           2,645.0000
# 3             4,308.9916           1,189.0000           2,257.0000
# 4             3,958.3451           1,084.0000           2,129.0000
#
#     total_main_arrests  violent_arrests_rates  property_arrests_rates  \
# 0           3,006.0000                37.7773                 62.0106
# 1           3,151.0000                35.0752                 70.1839
# 2           3,709.0000                35.7679                 88.9154
# 3           3,446.0000                40.2245                 76.3555
# 4           3,213.0000                36.9073                 72.4868
#
#    total_main_arrests_rates  sale_drug_total_tot_arrests_rate  \
# 0                   99.7879                            2.0914
# 1                  105.2591                            2.3718
# 2                  124.6832                            5.0761
# 3                  116.5799                            4.2626
# 4                  109.3941                            4.6645
#
#    poss_drug_total_tot_arrests_rate  disorder_arrests_tot_index_rate  \
# 0                           13.6105                          26.3910
# 1                           14.5312                          26.7574
# 2                           16.1695                          70.0902
# 3                           20.2983                          34.5748
# 4                           19.1687                          31.0852
#
#          pci_total_pop            pci_white            pci_black  \
# 0          38,977.0000          47,463.0000          28,146.0000
# 1          38,410.6000          46,657.6000          28,081.8000
# 2          37,844.2000          45,852.2000          28,017.6000
# 3          37,277.8000          45,046.8000          27,953.4000
# 4          36,711.4000          44,241.4000          27,889.2000
#
#               pci_hisp            emp_total       emp_total_male  \
# 0          27,448.0000         154,543.0000          83,626.0000
# 1          26,559.4000         153,815.4000          82,957.8000
# 2          25,670.8000         153,087.8000          82,289.6000
# 3          24,782.2000         152,360.2000          81,621.4000
# 4          23,893.6000         151,632.6000          80,953.2000
#
#       emp_total_female  emp_total_male_white  emp_total_female_white  \
# 0          70,917.0000           59,351.0000             46,642.0000
# 1          70,857.6000           59,519.2000             47,142.0000
# 2          70,798.2000           59,687.4000             47,642.0000
# 3          70,738.8000           59,855.6000             48,142.0000
# 4          70,679.4000           60,023.8000             48,642.0000
#
#    emp_total_male_black  emp_total_female_black  emp_total_male_hisp  \
# 0            4,533.0000              3,785.0000           7,153.0000
# 1            4,541.0000              3,809.6000           6,852.4000
# 2            4,549.0000              3,834.2000           6,551.8000
# 3            4,557.0000              3,858.8000           6,251.2000
# 4            4,565.0000              3,883.4000           5,950.6000
#
#    emp_total_female_hisp      emp_total_white      emp_total_black  \
# 0             5,660.0000         105,993.0000           8,318.0000
# 1             5,485.2000         106,661.2000           8,350.6000
# 2             5,310.4000         107,329.4000           8,383.2000
# 3             5,135.6000         107,997.6000           8,415.8000
# 4             4,960.8000         108,665.8000           8,448.4000
#
#         emp_total_hisp     PRIMARY_LATITUDE    PRIMARY_LONGITUDE  \
# 0          12,813.0000              61.1483            -149.1947
# 1          12,337.6000              61.1483            -149.1947
# 2          11,862.2000              61.1483            -149.1947
# 3          11,386.8000              61.1483            -149.1947
# 4          10,911.4000              61.1483            -149.1947
#
#         total_officers  total_officers_rate        perc_felonies  \
# 0             374.0000               1.2415             100.0000
# 1             374.0000               1.2493             100.0000
# 2             344.0000               1.1564             100.0000
# 3             372.0000               1.2585             100.0000
# 4             390.0000               1.3278             100.0000
#
#      perc_misdemeanors  prison_occupancy_count  jail_occupancy_count  \
# 0             100.0000                     nan                   nan
# 1             100.0000                     nan                   nan
# 2             100.0000                     nan                   nan
# 3             100.0000                     nan                   nan
# 4             100.0000                     nan                   nan
#
#    icspr_rep_code
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# __Get the numeric initial count columns for descriptives__

# %%
# initial_core_counts = initial_core_df.loc[:, ['POP100', 'White_count', 'Black_count', 'Hispanic_count','White_Males_All', 
#                                               'White_Females_All','Black_Males_All','Black_Females_All', 'Hispanic_Males_All', 
#                                               'Hispanic_Females_All','Pct_WYM', 'Pct_WYF', 'total_count_county', 'population', 
#                                               'murder', 'rape', 'robbery','aggravated_assault', 'simple_assault', 'burglary', 
#                                               'larceny', 'auto_theft', 'violent_crime', 'property_crime', 'total_main_crime', 
#                                               'violent_arrests', 'property_arrests','pci_total_pop', 'pci_white', 'pci_black', 
#                                               'pci_hisp', 'emp_total', 'emp_total_male', 'emp_total_female', 'emp_total_male_white', 
#                                               'emp_total_female_white', 'emp_total_male_black', 'emp_total_female_black', 
#                                               'emp_total_male_hisp', 'emp_total_female_hisp','total_officers', 
#                                               'prison_occupancy_count', 'jail_occupancy_count']]


initial_core_counts = initial_core_df.loc[:, ['ORI', 'AGENCY', 'YEAR', 'POP100', 'White_count', 'Black_count', 'Hispanic_count','Pct_WYM', 'Pct_WYF', 
                                              'total_count_county', 'population','murder', 'rape', 'robbery','aggravated_assault',
                                              'simple_assault', 'burglary','larceny', 'auto_theft', 'violent_crime', 
                                              'property_crime', 'total_main_crime','violent_arrests', 'property_arrests',
                                              'total_main_arrests', 'pci_total_pop', 'pci_white', 'pci_black','pci_hisp', 
                                              'emp_total','emp_total_white', 'emp_total_black','emp_total_hisp',
                                              'total_officers', 'total_officers_rate','prison_occupancy_count', 
                                              'jail_occupancy_count']]

initial_core_counts.describe()
# Out:
#                       YEAR               POP100          White_count  \
# count         312,572.0000         312,572.0000         312,572.0000
# mean            2,002.5000          32,707.6290          23,670.1834
# std                 7.5000         170,712.0550          96,483.2547
# min             1,990.0000               0.0000               0.0000
# 25%             1,996.0000           2,773.9500           2,278.9000
# 50%             2,002.5000           7,654.0000           6,312.4000
# 75%             2,009.0000          22,081.9250          17,754.6500
# max             2,015.0000       9,968,238.0000       5,086,368.0000
#
#                Black_count       Hispanic_count              Pct_WYM  \
# count         312,572.0000         312,572.0000         312,572.0000
# mean            4,101.2065           5,088.2823               0.1327
# std            33,208.8331          57,887.4193               0.0522
# min                 0.0000               0.0000               0.0000
# 25%                22.0000              47.0000               0.1118
# 50%               171.6000             205.5000               0.1257
# 75%             1,219.0500           1,062.0000               0.1402
# max         2,129,762.0000       4,910,727.0000               0.9000
#
#                    Pct_WYF   total_count_county           population  \
# count         312,572.0000         311,098.0000         312,563.0000
# mean                0.1199         356,161.3619          22,390.7515
# std                 0.0513         958,624.5763         105,684.6654
# min                 0.0000              45.0000               0.0000
# 25%                 0.0991          25,475.0000           2,742.0000
# 50%                 0.1131          76,645.0000           7,075.2000
# 75%                 0.1275         325,875.0000          18,446.5000
# max                 0.8267      10,170,292.0000       8,550,861.0000
#
#                     murder                 rape              robbery  \
# count         288,658.0000         312,563.0000         312,563.0000
# mean                1.4365               7.1894              37.6663
# std                17.9777              42.8105             595.5707
# min                -1.0000              -3.0000              -2.0000
# 25%                 0.0000               0.0000               0.0000
# 50%                 0.0000               1.0000               1.0000
# 75%                 0.0000               4.0000               5.0000
# max             3,452.0000           3,126.0000         100,280.0000
#
#         aggravated_assault       simple_assault             burglary  \
# count         312,563.0000         312,563.0000         312,563.0000
# mean               67.9290             208.0120             172.5880
# std               613.9946           1,168.9962           1,006.1934
# min                -4.0000             -11.0000               0.0000
# 25%                 1.0000               3.0000               5.0000
# 50%                 6.0000              27.0000              26.0000
# 75%                27.0000             114.0000              94.0000
# max            68,891.0000         111,776.0000         119,937.0000
#
#                    larceny           auto_theft        violent_crime  \
# count         312,563.0000         312,563.0000         312,572.0000
# mean              516.3510              68.3455             114.1080
# std             2,819.8601             936.7548           1,203.5084
# min                -1.0000              -1.0000              -2.0000
# 25%                16.0000               0.0000               1.0000
# 50%                85.0000               4.0000              10.0000
# 75%               307.0000              16.0000              38.0000
# max           268,620.0000         144,369.0000         174,542.0000
#
#             property_crime     total_main_crime      violent_arrests  \
# count         312,572.0000         312,572.0000         312,572.0000
# mean              757.2628             871.3707              41.4446
# std             4,473.1611           5,579.8459             405.7859
# min                -1.0000              -1.0000              -3.0000
# 25%                26.0000              29.0000               0.0000
# 50%               120.0000             133.0000               4.0000
# 75%               426.0000             468.0000              18.0000
# max           532,926.0000         707,468.0000          55,094.0000
#
#           property_arrests   total_main_arrests        pci_total_pop  \
# count         312,572.0000         312,572.0000         308,780.0000
# mean              124.8357             166.2803          21,353.9958
# std               682.4178           1,042.2958          11,651.9264
# min                 0.0000               0.0000           2,979.0000
# 25%                 1.0000               2.0000          14,620.2000
# 50%                16.0000              22.0000          18,743.8000
# 75%                74.0000              96.0000          24,363.7000
# max            70,022.0000         121,024.0000         340,850.0000
#
#                  pci_white            pci_black             pci_hisp  \
# count         308,780.0000         308,780.0000         308,780.0000
# mean           22,737.6495          13,360.1399          15,242.1407
# std            12,041.5187          14,114.3747          14,839.1073
# min                 0.0000               0.0000               0.0000
# 25%            15,759.8000           6,300.0000           9,332.3909
# 50%            20,124.0000          11,257.3500          12,975.3818
# 75%            25,894.0000          17,276.2000          18,002.4659
# max           340,850.0000         814,995.0000       1,801,413.0000
#
#                  emp_total      emp_total_white      emp_total_black  \
# count         308,780.0000         312,572.0000         312,572.0000
# mean           14,998.7972          11,445.8542           1,563.8586
# std            77,694.1010          48,869.8482          12,867.0885
# min                 1.0000               0.0000               0.0000
# 25%             1,171.5750             960.6000               4.8000
# 50%             3,371.8000           2,836.0000              56.6000
# 75%             9,870.8500           8,198.5250             431.0000
# max         4,588,568.0000       2,555,684.0000         867,733.0000
#
#             emp_total_hisp       total_officers  total_officers_rate  \
# count         312,572.0000         312,563.0000         312,563.0000
# mean            2,374.6920              45.1226               2.3531
# std            23,887.8039             389.5058               8.9417
# min                 0.0000               0.0000               0.0000
# 25%                24.4545               5.0000               1.2674
# 50%               120.8182              12.0000               1.7986
# 75%               610.0227              30.0000               2.5316
# max         2,179,990.0000          41,791.0000           1,511.0521
#
#        prison_occupancy_count  jail_occupancy_count
# count            266,715.0000          305,101.0000
# mean                 100.3706               53.4390
# std                  658.1264              265.4366
# min                    0.0000               -0.0966
# 25%                    5.5284                3.3631
# 50%                   18.4227               11.6830
# 75%                   59.2880               36.7660
# max               47,405.0000           17,562.0000

# %% [markdown]
# __Boxplots of core variables__

# %%
# sns.boxplot(initial_core_counts['total_main_crime'])
# plt.show()

# sns.FacetGrid(initial_core_counts, row='YEAR')

sns.boxplot(x = initial_core_counts["total_main_crime"], y = initial_core_counts["YEAR"])

# g = sns.FacetGrid(tips_data, row = "day")
# g = g.map(plt.hist, "tip")
plt.show()

# %%
initial_core_counts_yr_grpd = initial_core_counts.groupby('YEAR')
sns.distplot(initial_core_counts_yr_grpd['total_main_crime'], kde=False).set_title('Total Main Crime')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-144107e87b7f> in <module>
#       1 initial_core_counts_yr_grpd = initial_core_counts.groupby('YEAR')
# ----> 2 sns.distplot(initial_core_counts_yr_grpd['total_main_crime'], kde=False).set_title('Total Main Crime')
#       3 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     196             line, = ax.plot(0, a.mean())
#     197         else:
# --> 198             line, = ax.plot(a.mean(), 0)
#     199         color = line.get_color()
#     200         line.remove()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (312572,) and (1,)
